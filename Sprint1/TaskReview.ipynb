// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания Review

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

public class Product
{
    private string name;
    private decimal price;
    private int quantity;
    protected string category;
    internal string description;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set { price = value; }
    }

    public int Quantity
    {
        get { return quantity; }
        set { quantity = value; }
    }

    public Product(string name, decimal price, int quantity, string category, string description)
    {
        this.name = name;
        this.price = price;
        this.quantity = quantity;
        this.category = category;
        this.description = description;
    }

    public decimal GetTotalPrice()
    {
        return price * quantity;
    }

    public void UpdateQuantity(int amount)
    {
        quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {name}, Цена: {price} руб., Количество: {quantity}, Категория: {category}, Описание: {description}";
    }
}

public class Seller
{
    private string name;
    private string employeeId;
    protected decimal salary;
    internal string contactInfo;

    private List<Product> products = new List<Product>();

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public Seller(string name, string employeeId, decimal salary, string contactInfo)
    {
        this.name = name;
        this.employeeId = employeeId;
        this.salary = salary;
        this.contactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
        Console.WriteLine($"Продавец {name} добавил товар: {product.Name}");
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product.Quantity >= quantity)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($"Продано {quantity} шт. товара {product.Name}. Остаток: {product.Quantity}");
        }
        else
        {
            Console.WriteLine($"Недостаточно товара {product.Name} на складе!");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {name}, ID: {employeeId}, Контакт: {contactInfo}";
    }
}

public class Store
{
    private string storeName;
    private string location;
    public string storeHours;

    private List<Seller> sellers = new List<Seller>();
    private List<Product> allProducts = new List<Product>();

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public Store(string storeName, string location, string storeHours)
    {
        this.storeName = storeName;
        this.location = location;
        this.storeHours = storeHours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
        Console.WriteLine($"В магазин {storeName} добавлен продавец: {seller.Name}");
    }

    public void ListProducts()
    {
        Console.WriteLine($"Список товаров в магазине {storeName}:");
        foreach (var product in allProducts)
        {
            Console.WriteLine($"- {product.GetProductInfo()}");
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {storeName}, Адрес: {location}, Часы работы: {storeHours}";
    }
}

var product1 = new Product("Ноутбук", 50000, 10, "Электроника", "Мощный ноутбук для работы");
var product2 = new Product("Мышь", 1500, 50, "Аксессуары", "Беспроводная мышь");

var seller = new Seller("Мерц Кристина", "EMP001", 60000, "MertsKV@mail.ru");

var store = new Store("ДНС", "г.Тюмень, Мельникайте 70", "09:00 - 21:00");

seller.AddProduct(product1);
seller.AddProduct(product2);
Console.WriteLine();

store.AddSeller(seller);
Console.WriteLine();

seller.SellProduct(product1, 2);
Console.WriteLine();

Console.WriteLine(seller.GetSellerInfo());
Console.WriteLine(store.GetStoreInfo());
Console.WriteLine($"Общая стоимость товара '{product1.Name}': {product1.GetTotalPrice()} руб.");
// Out:
// Продавец Мерц Кристина добавил товар: Ноутбук
// Продавец Мерц Кристина добавил товар: Мышь
//
// В магазин ДНС добавлен продавец: Мерц Кристина
//
// Продано 2 шт. товара Ноутбук. Остаток: 8
//
// Продавец: Мерц Кристина, ID: EMP001, Контакт: MertsKV@mail.ru
// Магазин: ДНС, Адрес: г.Тюмень, Мельникайте 70, Часы работы: 09:00 - 21:00
// Общая стоимость товара 'Ноутбук': 400000 руб.
